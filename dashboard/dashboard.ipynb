# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
db.plot_dau_and_new_players()
# Out:
# Making API call
# {'DAU': [{'date': '2024-07-07', 'userCount': 1}, {'date': '2024-07-08', 'userCount': 2}], 'day1retention': {'returningPlayers': 1, 'retentionRate': 50}, 'day7retention': {'returningPlayers': 0, 'retentionRate': 0}, 'day30retention': {'returningPlayers': 0, 'retentionRate': 0}, 'yesterdayRetention': {'returningPlayers': 1, 'retentionRate': 50}, 'newPlayersPerDay': {'2024-07-08': 1, '2024-07-07': 1}, 'gamesPerModePerDay': {'2024-07-08': {'2': 1}}, 'totalPlayers': 2, 'medianGameDuration': 0.9426, 'inactivePlayerIds': []}
# [{'date': '2024-07-07', 'userCount': 1}, {'date': '2024-07-08', 'userCount': 2}]
# In: {'2024-07-08': 1, '2024-07-07': 1}
# Out: [{'date': '2024-07-08', 'newPlayers': 1}]
# [{'date': '2024-07-08', 'newPlayers': 1}]

# %%
db.plot_games_per_mode()
# Out:
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1607 ticks ([19109.0, ..., 20715.0]), which exceeds Locator.MAXTICKS (1000).
# ...

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  1                  50
# 1            Day 7                  0                   0
# 2           Day 30                  0                   0
# 3        Yesterday                  1                  50
# Median Game Duration: 0.94 min
# Total Players: 2
# ATH of DAU: 2
# Yesterday's DAU: 1 (50.00% of ATH)

# %%
db.list_inactive_players()
# Out:
# No inactive players found.

# %%
db.get_player_log('WHVK2d8qVc9Pt4deUyJ6NovNdSbP')
# Out:
# Error fetching action log for player WHVK2d8qVc9Pt4deUyJ6NovNdSbP: 404 Client Error: Not Found for url: http://127.0.0.1:5001/legion-32c6d/us-central1/getActionLog?playerId=WHVK2d8qVc9Pt4deUyJ6NovNdSbP

# %%
# db.get_game_log('0e762e3f-e156-4caa-8e45-2d7ef62e84e5')
